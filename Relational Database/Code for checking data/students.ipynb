# %%
# students table
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('students.csv')

# %%
data.dtypes
# Out:
# student_id      int64
# college_id      int64
# admission_id    int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# student_id      0
# college_id      0
# admission_id    0
# dtype: int64
