# %%
import pandas as pd
import numpy as np

# %%
#Uploading the sending_msg csv
data = pd.read_csv("sending_ms.csv", encoding = "latin-1")

# %%
data.dtypes
# Out:
# sending_ms_id     int64
# ms_name          object
# ms_type          object
# dtype: object
