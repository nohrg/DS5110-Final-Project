# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv('universities.csv')
data
# Out:
#       university_id                             institution_name  \
# 0            110404           California Institute of Technology
# 1            166027                           Harvard University
# 2            166683        Massachusetts Institute of Technology
# 3            190150  Columbia University in the City of New York
# 4            243744                          Stanford University
# ...             ...                                          ...
# 1856         497268    Arizona College of Nursing-Salt Lake City
# 1857         497912             Concorde Career College-Broadway
# 1858         498049        Arizona College of Nursing-Southfield
# 1859         498447      Arizona College of Nursing-Falls Church
# 1860         498456           Arizona College of Nursing-Ontario
#
#               state                                             region  year  \
# 0        California                  Far West (AK, CA, HI, NV, OR, WA)  2022
# ...

# %%
data.dtypes
# Out:
# university_id        int64
# institution_name    object
# state               object
# region              object
# year                 int64
# student_count        int64
# percent_admitted     int64
# percent_yield        int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# university_id       0
# institution_name    0
# state               0
# region              0
# year                0
# student_count       0
# percent_admitted    0
# percent_yield       0
# dtype: int64
