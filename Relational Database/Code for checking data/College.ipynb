# %%
#College Office table
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('college.csv')
data
# Out:
#      college_id  admission_id    gpa     sat   act  \
# 0             1         10528  11.00  1580.0  35.0
# 1             2         10532  10.95  1520.0   NaN
# 2             3         16650  10.93  1550.0   NaN
# 3             4        243176  10.92  1580.0   NaN
# 4             5         12785  10.90  1570.0   NaN
# ..          ...           ...    ...     ...   ...
# 531         532         10306   7.86     NaN   NaN
# 532         533         10103   7.69     NaN   NaN
# 533         534         10454   7.69     NaN   NaN
# 534         535         17927   7.43     NaN   NaN
# 535         536         10059   6.97     NaN   NaN
#
#                                 matric  university_id  hook_athlete  \
# 0         University of Southern Maine         161554          True
# 1       American International College         164447         False
# 2    Saint Elizabeth School of Nursing         152497         False
# 3                     Tufts University         168148         False
# ...

# %%
data.dtypes
# Out:
# college_id          int64
# admission_id        int64
# gpa               float64
# sat               float64
# act               float64
# matric             object
# university_id       int64
# hook_athlete         bool
# hook_first_gen       bool
# hook_legacy          bool
# dtype: object

# %%
# Checking missing values
data.isnull().sum()
# Out:
# college_id          0
# admission_id        0
# gpa                 0
# sat               177
# act               296
# matric              0
# university_id       0
# hook_athlete        0
# hook_first_gen      0
# hook_legacy         0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['sat']=data['sat'].replace(np.nan, 0)
data['act']=data['act'].replace(np.nan, 0)

# %%
data.isnull().sum()
# Out:
# college_id        0
# admission_id      0
# gpa               0
# sat               0
# act               0
# matric            0
# university_id     0
# hook_athlete      0
# hook_first_gen    0
# hook_legacy       0
# dtype: int64

# %%
data.to_csv('college_updated.csv')

# %%
# transforming the booleans
data['hook_athlete']= data['hook_athlete'].replace({True: 1, False: 0})
data['hook_first_gen']= data['hook_first_gen'].replace({True: 1, False: 0})
data['hook_legacy']= data['hook_legacy'].replace({True: 1, False: 0})
# Out:
# <ipython-input-13-6f603c026c28>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['hook_athlete']= data['hook_athlete'].replace({True: 1, False: 0})
# <ipython-input-13-6f603c026c28>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['hook_first_gen']= data['hook_first_gen'].replace({True: 1, False: 0})
# ...

# %%
data
# Out:
#      college_id  admission_id    gpa     sat   act  \
# 0             1         10528  11.00  1580.0  35.0
# 1             2         10532  10.95  1520.0   0.0
# 2             3         16650  10.93  1550.0   0.0
# 3             4        243176  10.92  1580.0   0.0
# 4             5         12785  10.90  1570.0   0.0
# ..          ...           ...    ...     ...   ...
# 531         532         10306   7.86     0.0   0.0
# 532         533         10103   7.69     0.0   0.0
# 533         534         10454   7.69     0.0   0.0
# 534         535         17927   7.43     0.0   0.0
# 535         536         10059   6.97     0.0   0.0
#
#                                 matric  university_id  hook_athlete  \
# 0         University of Southern Maine         161554             1
# 1       American International College         164447             0
# 2    Saint Elizabeth School of Nursing         152497             0
# 3                     Tufts University         168148             0
# ...

# %%
data.dtypes
# Out:
# college_id          int64
# admission_id        int64
# gpa               float64
# sat               float64
# act               float64
# matric             object
# university_id       int64
# hook_athlete        int64
# hook_first_gen      int64
# hook_legacy         int64
# dtype: object

# %%
data.to_csv('updated_college')
